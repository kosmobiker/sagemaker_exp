# %%
import os
import boto3
from botocore.exceptions import ClientError
import awswrangler as wr
import pandas as pd
import numpy as np

from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from tqdm import tqdm 
from sklearn.base import BaseEstimator, TransformerMixin
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import roc_auc_score

import gensim.downloader as api
import logging 
# Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

import warnings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 500)
pd.options.mode.chained_assignment = None
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#list all buckets
s3 = boto3.resource('s3')
buckets = [bucket.name for bucket in s3.buckets.all()]
print(buckets)
# Out:
# INFO - 13:58:54: Found credentials in shared credentials file: ~/.aws/credentials
# ['godel-tf-state', 'godelsagemaker', 'sagemaker-eu-west-1-798631296162']

# %%
def get_list_of_objects_s3(operation_parameters):
    """This function is used to create a generator
    that will yield paths from S3 for the files that 
    are not older than N days
    Currently N is set to 7 because glue job runs onece per week
    Args:
        operation_parameters (_type_): params for the generator
    Yields:
        _type_: S3 path
    """
    s3 = boto3.client('s3')
    paginator = s3.get_paginator('list_objects_v2')
    page_iterator = paginator.paginate(**operation_parameters)
    for page in page_iterator:
        for content in page.get('Contents'):
            # if content.get('LastModified') > utc.localize(datetime.now() - timedelta(days=7)):
                yield content.get('Key')
                
bucket = 'godelsagemaker'
params = {
        'Bucket' : bucket,
        'Prefix' : "data/",
        }
for i in get_list_of_objects_s3(params):
    print(i)
# Out:
# data/toxic_data.csv

# %%
SUBGROUP_AUC = 'subgroup_auc'
BPSN_AUC = 'bpsn_auc'  # stands for background positive, subgroup negative
BNSP_AUC = 'bnsp_auc'  # stands for background negative, subgroup positive

def compute_auc(y_true, y_pred):
    try:
        return roc_auc_score(y_true, y_pred)
    except ValueError:
        return np.nan

def compute_subgroup_auc(df, subgroup, label, oof_name):
    subgroup_examples = df[df[subgroup]]
    return compute_auc(subgroup_examples[label], subgroup_examples[oof_name])

def compute_bpsn_auc(df, subgroup, label, oof_name):
    """Computes the AUC of the within-subgroup negative examples and the background positive examples."""
    subgroup_negative_examples = df[df[subgroup] & ~df[label]]
    non_subgroup_positive_examples = df[~df[subgroup] & df[label]]
    examples = subgroup_negative_examples.append(non_subgroup_positive_examples)
    return compute_auc(examples[label], examples[oof_name])

def compute_bnsp_auc(df, subgroup, label, oof_name):
    """Computes the AUC of the within-subgroup positive examples and the background negative examples."""
    subgroup_positive_examples = df[df[subgroup] & df[label]]
    non_subgroup_negative_examples = df[~df[subgroup] & ~df[label]]
    examples = subgroup_positive_examples.append(non_subgroup_negative_examples)
    return compute_auc(examples[label], examples[oof_name])

def compute_bias_metrics_for_model(dataset,
                                   subgroups,
                                   model,
                                   label_col,
                                   include_asegs=False):
    """Computes per-subgroup metrics for all subgroups and one model."""
    records = []
    for subgroup in subgroups:
        record = {
            'subgroup': subgroup,
            'subgroup_size': len(dataset[dataset[subgroup]])
        }
        record[SUBGROUP_AUC] = compute_subgroup_auc(dataset, subgroup, label_col, model)
        record[BPSN_AUC] = compute_bpsn_auc(dataset, subgroup, label_col, model)
        record[BNSP_AUC] = compute_bnsp_auc(dataset, subgroup, label_col, model)
        records.append(record)
    return pd.DataFrame(records).sort_values('subgroup_auc', ascending=True)

def calculate_overall_auc(df, oof_name):
    true_labels = df['toxicity']
    predicted_labels = df[oof_name]
    return roc_auc_score(true_labels, predicted_labels)

def power_mean(series, p):
    total = sum(np.power(series, p))
    return np.power(total / len(series), 1 / p)

def get_final_metric(bias_df, overall_auc, POWER=-5, OVERALL_MODEL_WEIGHT=0.25):
    bias_score = np.average([
        power_mean(bias_df[SUBGROUP_AUC], POWER),
        power_mean(bias_df[BPSN_AUC], POWER),
        power_mean(bias_df[BNSP_AUC], POWER)
    ])
    return (OVERALL_MODEL_WEIGHT * overall_auc) + ((1 - OVERALL_MODEL_WEIGHT) * bias_score)

# %%
chunks = wr.s3.read_csv(path=f's3://{bucket}/data/toxic_data.csv', chunksize=100000)
df = pd.concat(chunks)
df['comment_text'] = df['comment_text'].fillna("")
sample = df.sample(1_000_000)
train_df = sample[sample['split'] == 'train']
test_df = sample[sample['split'] != 'train']

# %%
identity_columns = ['male', 'female', 'homosexual_gay_or_lesbian', 'christian', 'jewish', 'muslim', 'black', 'white', 'psychiatric_or_mental_illness']
for col in identity_columns + ['toxicity']:
    train_df.loc[:, col] = np.where(train_df[col] >= 0.5, True, False)
    test_df.loc[:, col] = np.where(test_df[col] >= 0.5, True, False)
y_train = train_df['toxicity']
y_test = test_df['toxicity']

# %%
train_lists = [simple_preprocess(doc) for doc in tqdm(train_df['comment_text'])]
test_lists = [simple_preprocess(doc) for doc in tqdm(test_df['comment_text'])]
# Out:
# 100%|██████████| 902855/902855 [00:54<00:00, 16488.33it/s]
# 100%|██████████| 97145/97145 [00:05<00:00, 17215.93it/s]

# %% [markdown]
# ## Custom Word2Vec

# %%
#thanks to https://ethen8181.github.io/machine-learning/keras/text_classification/word2vec_text_classification.html

class GensimWord2VecVectorizer(BaseEstimator, TransformerMixin):
    """
    Word vectors are averaged across to create the document-level vectors/features.
    gensim's own gensim.sklearn_api.W2VTransformer doesn't support out of vocabulary words,
    hence we roll out our own.
    All the parameters are gensim.models.Word2Vec's parameters.
    https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.Word2Vec
    """

    def __init__(self, vector_size=100, alpha=0.025, window=5, min_count=5, max_vocab_size=None,
                 sample=0.001, seed=1, workers=3, min_alpha=0.0001, sg=0, hs=0, negative=5,
                 ns_exponent=0.75, cbow_mean=1, hashfxn=hash, epochs=5, null_word=0,
                 trim_rule=None, sorted_vocab=1, batch_words=10000, compute_loss=False,
                 callbacks=(), max_final_vocab=None):
        self.vector_size = vector_size
        self.alpha = alpha
        self.window = window
        self.min_count = min_count
        self.max_vocab_size = max_vocab_size
        self.sample = sample
        self.seed = seed
        self.workers = workers
        self.min_alpha = min_alpha
        self.sg = sg
        self.hs = hs
        self.negative = negative
        self.ns_exponent = ns_exponent
        self.cbow_mean = cbow_mean
        self.hashfxn = hashfxn
        self.epochs = epochs
        self.null_word = null_word
        self.trim_rule = trim_rule
        self.sorted_vocab = sorted_vocab
        self.batch_words = batch_words
        self.compute_loss = compute_loss
        self.callbacks = callbacks
        self.max_final_vocab = max_final_vocab
    
    def _get_embedding(self, words):
        valid_words = [word for word in words if word in self.model_.wv.key_to_index]
        if valid_words:
            embedding = np.zeros((len(valid_words), self.vector_size), dtype=np.float32)
            for idx, word in enumerate(valid_words):
                embedding[idx] = self.model_.wv[word]

            return np.mean(embedding, axis=0)
        else:
            return np.zeros(self.vector_size)
    
    def fit(self, X, y=None):
        self.model_ = Word2Vec(
            sentences=X, corpus_file=None,
            vector_size=self.vector_size, alpha=self.alpha, window=self.window, min_count=self.min_count,
            max_vocab_size=self.max_vocab_size, sample=self.sample, seed=self.seed,
            workers=self.workers, min_alpha=self.min_alpha, sg=self.sg, hs=self.hs,
            negative=self.negative, ns_exponent=self.ns_exponent, cbow_mean=self.cbow_mean,
            hashfxn=self.hashfxn, epochs=self.epochs, null_word=self.null_word,
            trim_rule=self.trim_rule, sorted_vocab=self.sorted_vocab, batch_words=self.batch_words,
            compute_loss=self.compute_loss, callbacks=self.callbacks,
            max_final_vocab=self.max_final_vocab)
        return self

    def transform(self, X):
        X_embeddings = np.array([self._get_embedding(words) for words in X])
        return X_embeddings

# %%
gensim_word2vec_tr = GensimWord2VecVectorizer(vector_size=100, min_count=1, sg=1, alpha=0.01, epochs=5)
# xgb = XGBClassifier(learning_rate=0.01, n_estimators=100, n_jobs=-1)
lr = LogisticRegression(max_iter=10_000)
# rf = RandomForestClassifier(n_estimators=300)

# %%
# %%time

#1_000_000
pipeline1 = Pipeline([
        ('w2v', gensim_word2vec_tr), 
        ('LogReg', lr)
    ])
pipeline1.fit(train_lists, y_train)
oof_name = 'predicted_target'
test_df[oof_name] = pipeline1.predict_proba(test_lists)[:, 1]
oof_name = 'predicted_target'
bias_metrics_df = compute_bias_metrics_for_model(test_df, identity_columns, oof_name, 'toxicity')
bias_metrics_df
# Out:
# INFO - 14:03:31: collecting all words and their counts
# INFO - 14:03:31: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 14:03:31: PROGRESS: at sentence #10000, processed 498311 words, keeping 26688 word types
# INFO - 14:03:31: PROGRESS: at sentence #20000, processed 995634 words, keeping 36525 word types
# INFO - 14:03:31: PROGRESS: at sentence #30000, processed 1493604 words, keeping 43613 word types
# INFO - 14:03:31: PROGRESS: at sentence #40000, processed 1993446 words, keeping 49425 word types
# INFO - 14:03:31: PROGRESS: at sentence #50000, processed 2490094 words, keeping 54320 word types
# INFO - 14:03:31: PROGRESS: at sentence #60000, processed 2989277 words, keeping 58830 word types
# INFO - 14:03:31: PROGRESS: at sentence #70000, processed 3483569 words, keeping 62805 word types
# INFO - 14:03:31: PROGRESS: at sentence #80000, processed 3978620 words, keeping 66541 word types
# INFO - 14:03:31: PROGRESS: at sentence #90000, processed 4481202 words, keeping 70070 word types
# INFO - 14:03:32: PROGRESS: at sentence #100000, processed 4977751 words, keeping 73260 word types
# INFO - 14:03:32: PROGRESS: at sentence #110000, processed 5481023 words, keeping 76196 word types
# INFO - 14:03:32: PROGRESS: at sentence #120000, processed 5979625 words, keeping 79133 word types
# INFO - 14:03:32: PROGRESS: at sentence #130000, processed 6475683 words, keeping 81969 word types
# INFO - 14:03:32: PROGRESS: at sentence #140000, processed 6971717 words, keeping 84611 word types
# INFO - 14:03:32: PROGRESS: at sentence #150000, processed 7475776 words, keeping 87429 word types
# INFO - 14:03:32: PROGRESS: at sentence #160000, processed 7969878 words, keeping 89993 word types
# INFO - 14:03:32: PROGRESS: at sentence #170000, processed 8459106 words, keeping 92323 word types
# INFO - 14:03:32: PROGRESS: at sentence #180000, processed 8957306 words, keeping 94746 word types
# INFO - 14:03:33: PROGRESS: at sentence #190000, processed 9451061 words, keeping 96941 word types
# INFO - 14:03:33: PROGRESS: at sentence #200000, processed 9946315 words, keeping 99162 word types
# INFO - 14:03:33: PROGRESS: at sentence #210000, processed 10429983 words, keeping 101245 word types
# INFO - 14:03:33: PROGRESS: at sentence #220000, processed 10927091 words, keeping 103499 word types
# INFO - 14:03:33: PROGRESS: at sentence #230000, processed 11420516 words, keeping 105479 word types
# INFO - 14:03:33: PROGRESS: at sentence #240000, processed 11913827 words, keeping 107555 word types
# INFO - 14:03:33: PROGRESS: at sentence #250000, processed 12414457 words, keeping 109589 word types
# INFO - 14:03:33: PROGRESS: at sentence #260000, processed 12911762 words, keeping 111650 word types
# INFO - 14:03:33: PROGRESS: at sentence #270000, processed 13410990 words, keeping 113603 word types
# INFO - 14:03:33: PROGRESS: at sentence #280000, processed 13905848 words, keeping 115451 word types
# INFO - 14:03:34: PROGRESS: at sentence #290000, processed 14401810 words, keeping 117327 word types
# INFO - 14:03:34: PROGRESS: at sentence #300000, processed 14898992 words, keeping 119222 word types
# INFO - 14:03:34: PROGRESS: at sentence #310000, processed 15399646 words, keeping 120952 word types
# INFO - 14:03:34: PROGRESS: at sentence #320000, processed 15891275 words, keeping 122747 word types
# INFO - 14:03:34: PROGRESS: at sentence #330000, processed 16388966 words, keeping 124446 word types
# INFO - 14:03:34: PROGRESS: at sentence #340000, processed 16882329 words, keeping 126174 word types
# INFO - 14:03:34: PROGRESS: at sentence #350000, processed 17385258 words, keeping 127886 word types
# INFO - 14:03:34: PROGRESS: at sentence #360000, processed 17882936 words, keeping 129457 word types
# INFO - 14:03:35: PROGRESS: at sentence #370000, processed 18383670 words, keeping 131158 word types
# INFO - 14:03:35: PROGRESS: at sentence #380000, processed 18887287 words, keeping 132837 word types
# INFO - 14:03:35: PROGRESS: at sentence #390000, processed 19384572 words, keeping 134395 word types
# INFO - 14:03:35: PROGRESS: at sentence #400000, processed 19880500 words, keeping 136040 word types
# INFO - 14:03:35: PROGRESS: at sentence #410000, processed 20372354 words, keeping 137523 word types
# INFO - 14:03:35: PROGRESS: at sentence #420000, processed 20858223 words, keeping 139046 word types
# INFO - 14:03:35: PROGRESS: at sentence #430000, processed 21351787 words, keeping 140525 word types
# INFO - 14:03:35: PROGRESS: at sentence #440000, processed 21840526 words, keeping 142151 word types
# INFO - 14:03:35: PROGRESS: at sentence #450000, processed 22335723 words, keeping 143550 word types
# INFO - 14:03:36: PROGRESS: at sentence #460000, processed 22827506 words, keeping 145013 word types
# INFO - 14:03:36: PROGRESS: at sentence #470000, processed 23323258 words, keeping 146515 word types
# INFO - 14:03:36: PROGRESS: at sentence #480000, processed 23813620 words, keeping 147996 word types
# INFO - 14:03:36: PROGRESS: at sentence #490000, processed 24310906 words, keeping 149477 word types
# INFO - 14:03:36: PROGRESS: at sentence #500000, processed 24811213 words, keeping 150880 word types
# INFO - 14:03:36: PROGRESS: at sentence #510000, processed 25296409 words, keeping 152356 word types
# INFO - 14:03:36: PROGRESS: at sentence #520000, processed 25790566 words, keeping 153743 word types
# INFO - 14:03:36: PROGRESS: at sentence #530000, processed 26288637 words, keeping 155177 word types
# INFO - 14:03:36: PROGRESS: at sentence #540000, processed 26777510 words, keeping 156447 word types
# INFO - 14:03:37: PROGRESS: at sentence #550000, processed 27276027 words, keeping 157813 word types
# INFO - 14:03:37: PROGRESS: at sentence #560000, processed 27773039 words, keeping 159178 word types
# INFO - 14:03:37: PROGRESS: at sentence #570000, processed 28269566 words, keeping 160527 word types
# INFO - 14:03:37: PROGRESS: at sentence #580000, processed 28767717 words, keeping 161946 word types
# INFO - 14:03:37: PROGRESS: at sentence #590000, processed 29265198 words, keeping 163117 word types
# INFO - 14:03:37: PROGRESS: at sentence #600000, processed 29759026 words, keeping 164486 word types
# INFO - 14:03:37: PROGRESS: at sentence #610000, processed 30258706 words, keeping 165815 word types
# INFO - 14:03:37: PROGRESS: at sentence #620000, processed 30746288 words, keeping 167090 word types
# INFO - 14:03:37: PROGRESS: at sentence #630000, processed 31244636 words, keeping 168320 word types
# INFO - 14:03:38: PROGRESS: at sentence #640000, processed 31735716 words, keeping 169558 word types
# INFO - 14:03:38: PROGRESS: at sentence #650000, processed 32229030 words, keeping 170806 word types
# INFO - 14:03:38: PROGRESS: at sentence #660000, processed 32729603 words, keeping 172138 word types
# INFO - 14:03:38: PROGRESS: at sentence #670000, processed 33226759 words, keeping 173348 word types
# INFO - 14:03:38: PROGRESS: at sentence #680000, processed 33723568 words, keeping 174510 word types
# INFO - 14:03:38: PROGRESS: at sentence #690000, processed 34217983 words, keeping 175651 word types
# INFO - 14:03:38: PROGRESS: at sentence #700000, processed 34714345 words, keeping 176844 word types
# INFO - 14:03:38: PROGRESS: at sentence #710000, processed 35216645 words, keeping 178055 word types
# INFO - 14:03:38: PROGRESS: at sentence #720000, processed 35714135 words, keeping 179201 word types
# INFO - 14:03:39: PROGRESS: at sentence #730000, processed 36215637 words, keeping 180317 word types
# INFO - 14:03:39: PROGRESS: at sentence #740000, processed 36716535 words, keeping 181489 word types
# INFO - 14:03:39: PROGRESS: at sentence #750000, processed 37210698 words, keeping 182625 word types
# INFO - 14:03:39: PROGRESS: at sentence #760000, processed 37699295 words, keeping 183848 word types
# INFO - 14:03:39: PROGRESS: at sentence #770000, processed 38200610 words, keeping 185011 word types
# INFO - 14:03:39: PROGRESS: at sentence #780000, processed 38685481 words, keeping 186116 word types
# INFO - 14:03:39: PROGRESS: at sentence #790000, processed 39169311 words, keeping 187219 word types
# INFO - 14:03:39: PROGRESS: at sentence #800000, processed 39664460 words, keeping 188355 word types
# INFO - 14:03:40: PROGRESS: at sentence #810000, processed 40153449 words, keeping 189469 word types
# INFO - 14:03:40: PROGRESS: at sentence #820000, processed 40638305 words, keeping 190573 word types
# INFO - 14:03:40: PROGRESS: at sentence #830000, processed 41132423 words, keeping 191716 word types
# INFO - 14:03:40: PROGRESS: at sentence #840000, processed 41627775 words, keeping 192855 word types
# INFO - 14:03:40: PROGRESS: at sentence #850000, processed 42122913 words, keeping 193971 word types
# INFO - 14:03:40: PROGRESS: at sentence #860000, processed 42623488 words, keeping 195057 word types
# INFO - 14:03:40: PROGRESS: at sentence #870000, processed 43122064 words, keeping 196173 word types
# INFO - 14:03:41: PROGRESS: at sentence #880000, processed 43626795 words, keeping 197259 word types
# INFO - 14:03:41: PROGRESS: at sentence #890000, processed 44121099 words, keeping 198326 word types
# INFO - 14:03:41: PROGRESS: at sentence #900000, processed 44617028 words, keeping 199397 word types
# INFO - 14:03:41: collected 199656 word types from a corpus of 44760398 raw words and 902855 sentences
# INFO - 14:03:41: Creating a fresh vocabulary
# INFO - 14:03:42: Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 199656 unique words (100.00% of original 199656, drops 0)', 'datetime': '2022-08-24T14:03:42.299134', 'gensim': '4.2.0', 'python': '3.9.13 | packaged by conda-forge | (main, May 27 2022, 16:56:21) \n[GCC 10.3.0]', 'platform': 'Linux-4.14.287-215.504.amzn2.x86_64-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO - 14:03:42: Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 44760398 word corpus (100.00% of original 44760398, drops 0)', 'datetime': '2022-08-24T14:03:42.301048', 'gensim': '4.2.0', 'python': '3.9.13 | packaged by conda-forge | (main, May 27 2022, 16:56:21) \n[GCC 10.3.0]', 'platform': 'Linux-4.14.287-215.504.amzn2.x86_64-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO - 14:03:43: deleting the raw counts dictionary of 199656 items
# INFO - 14:03:43: sample=0.001 downsamples 50 most-common words
# INFO - 14:03:43: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 35111907.09877143 word corpus (78.4%% of prior 44760398)', 'datetime': '2022-08-24T14:03:43.190914', 'gensim': '4.2.0', 'python': '3.9.13 | packaged by conda-forge | (main, May 27 2022, 16:56:21) \n[GCC 10.3.0]', 'platform': 'Linux-4.14.287-215.504.amzn2.x86_64-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO - 14:03:44: estimated required memory for 199656 words and 100 dimensions: 259552800 bytes
# INFO - 14:03:44: resetting layer weights
# INFO - 14:03:44: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-08-24T14:03:44.733274', 'gensim': '4.2.0', 'python': '3.9.13 | packaged by conda-forge | (main, May 27 2022, 16:56:21) \n[GCC 10.3.0]', 'platform': 'Linux-4.14.287-215.504.amzn2.x86_64-x86_64-with-glibc2.31', 'event': 'build_vocab'}
# INFO - 14:03:44: Word2Vec lifecycle event {'msg': 'training model with 3 workers on 199656 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-08-24T14:03:44.734551', 'gensim': '4.2.0', 'python': '3.9.13 | packaged by conda-forge | (main, May 27 2022, 16:56:21) \n[GCC 10.3.0]', 'platform': 'Linux-4.14.287-215.504.amzn2.x86_64-x86_64-with-glibc2.31', 'event': 'train'}
# INFO - 14:03:45: EPOCH 0 - PROGRESS: at 0.36% examples, 122301 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:46: EPOCH 0 - PROGRESS: at 1.02% examples, 176698 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:47: EPOCH 0 - PROGRESS: at 1.68% examples, 192387 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:48: EPOCH 0 - PROGRESS: at 2.37% examples, 201985 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:49: EPOCH 0 - PROGRESS: at 3.06% examples, 208109 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:50: EPOCH 0 - PROGRESS: at 3.74% examples, 212445 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:51: EPOCH 0 - PROGRESS: at 4.38% examples, 214226 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:53: EPOCH 0 - PROGRESS: at 5.07% examples, 216647 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:54: EPOCH 0 - PROGRESS: at 5.70% examples, 216758 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:55: EPOCH 0 - PROGRESS: at 6.38% examples, 217969 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:56: EPOCH 0 - PROGRESS: at 7.07% examples, 219037 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:57: EPOCH 0 - PROGRESS: at 7.76% examples, 220101 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:58: EPOCH 0 - PROGRESS: at 8.40% examples, 220378 words/s, in_qsize 5, out_qsize 0
# INFO - 14:03:59: EPOCH 0 - PROGRESS: at 9.11% examples, 221652 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:00: EPOCH 0 - PROGRESS: at 9.77% examples, 222291 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:01: EPOCH 0 - PROGRESS: at 10.46% examples, 222640 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:02: EPOCH 0 - PROGRESS: at 11.08% examples, 221697 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:03: EPOCH 0 - PROGRESS: at 11.71% examples, 221824 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:04: EPOCH 0 - PROGRESS: at 12.40% examples, 222621 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:05: EPOCH 0 - PROGRESS: at 13.05% examples, 222946 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:06: EPOCH 0 - PROGRESS: at 13.75% examples, 223611 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:07: EPOCH 0 - PROGRESS: at 14.41% examples, 223559 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:08: EPOCH 0 - PROGRESS: at 15.09% examples, 223747 words/s, in_qsize 4, out_qsize 1
# INFO - 14:04:09: EPOCH 0 - PROGRESS: at 15.76% examples, 224429 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:10: EPOCH 0 - PROGRESS: at 16.39% examples, 224293 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:11: EPOCH 0 - PROGRESS: at 17.10% examples, 224901 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:12: EPOCH 0 - PROGRESS: at 17.76% examples, 225123 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:13: EPOCH 0 - PROGRESS: at 18.46% examples, 225291 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:14: EPOCH 0 - PROGRESS: at 19.14% examples, 225696 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:15: EPOCH 0 - PROGRESS: at 19.81% examples, 225645 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:16: EPOCH 0 - PROGRESS: at 20.49% examples, 225889 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:17: EPOCH 0 - PROGRESS: at 21.13% examples, 225725 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:18: EPOCH 0 - PROGRESS: at 21.80% examples, 225733 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:19: EPOCH 0 - PROGRESS: at 22.45% examples, 225445 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:20: EPOCH 0 - PROGRESS: at 23.16% examples, 225667 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:21: EPOCH 0 - PROGRESS: at 23.82% examples, 225699 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:22: EPOCH 0 - PROGRESS: at 24.51% examples, 225697 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:23: EPOCH 0 - PROGRESS: at 25.20% examples, 226089 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:25: EPOCH 0 - PROGRESS: at 25.90% examples, 226179 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:26: EPOCH 0 - PROGRESS: at 26.57% examples, 226233 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:27: EPOCH 0 - PROGRESS: at 27.22% examples, 226263 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:28: EPOCH 0 - PROGRESS: at 27.90% examples, 226370 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:29: EPOCH 0 - PROGRESS: at 28.53% examples, 226368 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:30: EPOCH 0 - PROGRESS: at 29.21% examples, 226589 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:31: EPOCH 0 - PROGRESS: at 29.88% examples, 226652 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:32: EPOCH 0 - PROGRESS: at 30.48% examples, 226304 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:33: EPOCH 0 - PROGRESS: at 31.06% examples, 225597 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:34: EPOCH 0 - PROGRESS: at 31.64% examples, 224924 words/s, in_qsize 4, out_qsize 1
# INFO - 14:04:35: EPOCH 0 - PROGRESS: at 32.24% examples, 224503 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:36: EPOCH 0 - PROGRESS: at 32.79% examples, 223839 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:37: EPOCH 0 - PROGRESS: at 33.39% examples, 223441 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:38: EPOCH 0 - PROGRESS: at 33.94% examples, 222879 words/s, in_qsize 6, out_qsize 0
# INFO - 14:04:39: EPOCH 0 - PROGRESS: at 34.47% examples, 222199 words/s, in_qsize 4, out_qsize 1
# INFO - 14:04:40: EPOCH 0 - PROGRESS: at 35.05% examples, 221678 words/s, in_qsize 6, out_qsize 2
# INFO - 14:04:41: EPOCH 0 - PROGRESS: at 35.64% examples, 221325 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:42: EPOCH 0 - PROGRESS: at 36.22% examples, 220957 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:43: EPOCH 0 - PROGRESS: at 36.79% examples, 220488 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:44: EPOCH 0 - PROGRESS: at 37.43% examples, 220401 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:45: EPOCH 0 - PROGRESS: at 38.11% examples, 220591 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:46: EPOCH 0 - PROGRESS: at 38.76% examples, 220723 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:47: EPOCH 0 - PROGRESS: at 39.44% examples, 220872 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:48: EPOCH 0 - PROGRESS: at 40.09% examples, 220929 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:49: EPOCH 0 - PROGRESS: at 40.72% examples, 221014 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:50: EPOCH 0 - PROGRESS: at 41.36% examples, 221055 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:51: EPOCH 0 - PROGRESS: at 42.00% examples, 221039 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:52: EPOCH 0 - PROGRESS: at 42.67% examples, 221168 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:53: EPOCH 0 - PROGRESS: at 43.33% examples, 221320 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:54: EPOCH 0 - PROGRESS: at 44.01% examples, 221549 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:55: EPOCH 0 - PROGRESS: at 44.67% examples, 221606 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:56: EPOCH 0 - PROGRESS: at 45.33% examples, 221742 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:57: EPOCH 0 - PROGRESS: at 46.04% examples, 221874 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:58: EPOCH 0 - PROGRESS: at 46.72% examples, 221990 words/s, in_qsize 5, out_qsize 0
# INFO - 14:04:59: EPOCH 0 - PROGRESS: at 47.37% examples, 222005 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:00: EPOCH 0 - PROGRESS: at 48.05% examples, 222088 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:01: EPOCH 0 - PROGRESS: at 48.70% examples, 222140 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:02: EPOCH 0 - PROGRESS: at 49.28% examples, 221876 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:03: EPOCH 0 - PROGRESS: at 49.90% examples, 221691 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:04: EPOCH 0 - PROGRESS: at 50.57% examples, 221848 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:05: EPOCH 0 - PROGRESS: at 51.22% examples, 221857 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:06: EPOCH 0 - PROGRESS: at 51.91% examples, 221974 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:07: EPOCH 0 - PROGRESS: at 52.58% examples, 222080 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:09: EPOCH 0 - PROGRESS: at 53.28% examples, 222167 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:10: EPOCH 0 - PROGRESS: at 53.97% examples, 222374 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:11: EPOCH 0 - PROGRESS: at 54.63% examples, 222504 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:12: EPOCH 0 - PROGRESS: at 55.29% examples, 222548 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:13: EPOCH 0 - PROGRESS: at 55.99% examples, 222648 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:14: EPOCH 0 - PROGRESS: at 56.67% examples, 222768 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:15: EPOCH 0 - PROGRESS: at 57.33% examples, 222897 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:16: EPOCH 0 - PROGRESS: at 57.98% examples, 222923 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:17: EPOCH 0 - PROGRESS: at 58.64% examples, 223024 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:18: EPOCH 0 - PROGRESS: at 59.30% examples, 223044 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:19: EPOCH 0 - PROGRESS: at 59.97% examples, 223135 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:20: EPOCH 0 - PROGRESS: at 60.63% examples, 223230 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:21: EPOCH 0 - PROGRESS: at 61.23% examples, 223057 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:22: EPOCH 0 - PROGRESS: at 61.85% examples, 222930 words/s, in_qsize 6, out_qsize 0
# INFO - 14:05:23: EPOCH 0 - PROGRESS: at 62.52% examples, 222954 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:24: EPOCH 0 - PROGRESS: at 63.21% examples, 223131 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:25: EPOCH 0 - PROGRESS: at 63.87% examples, 223196 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:26: EPOCH 0 - PROGRESS: at 64.54% examples, 223235 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:27: EPOCH 0 - PROGRESS: at 65.20% examples, 223339 words/s, in_qsize 6, out_qsize 0
# INFO - 14:05:28: EPOCH 0 - PROGRESS: at 65.87% examples, 223345 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:29: EPOCH 0 - PROGRESS: at 66.56% examples, 223463 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:30: EPOCH 0 - PROGRESS: at 67.20% examples, 223488 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:31: EPOCH 0 - PROGRESS: at 67.85% examples, 223517 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:32: EPOCH 0 - PROGRESS: at 68.53% examples, 223556 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:33: EPOCH 0 - PROGRESS: at 69.15% examples, 223501 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:34: EPOCH 0 - PROGRESS: at 69.83% examples, 223587 words/s, in_qsize 6, out_qsize 0
# INFO - 14:05:35: EPOCH 0 - PROGRESS: at 70.52% examples, 223671 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:36: EPOCH 0 - PROGRESS: at 71.21% examples, 223693 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:37: EPOCH 0 - PROGRESS: at 71.88% examples, 223776 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:38: EPOCH 0 - PROGRESS: at 72.52% examples, 223765 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:39: EPOCH 0 - PROGRESS: at 73.22% examples, 223918 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:40: EPOCH 0 - PROGRESS: at 73.87% examples, 223927 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:41: EPOCH 0 - PROGRESS: at 74.52% examples, 224012 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:42: EPOCH 0 - PROGRESS: at 75.19% examples, 224091 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:43: EPOCH 0 - PROGRESS: at 75.84% examples, 224066 words/s, in_qsize 6, out_qsize 0
# INFO - 14:05:44: EPOCH 0 - PROGRESS: at 76.54% examples, 224199 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:45: EPOCH 0 - PROGRESS: at 77.18% examples, 224211 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:46: EPOCH 0 - PROGRESS: at 77.82% examples, 224193 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:47: EPOCH 0 - PROGRESS: at 78.50% examples, 224278 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:48: EPOCH 0 - PROGRESS: at 79.17% examples, 224271 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:49: EPOCH 0 - PROGRESS: at 79.82% examples, 224345 words/s, in_qsize 4, out_qsize 1
# INFO - 14:05:50: EPOCH 0 - PROGRESS: at 80.50% examples, 224402 words/s, in_qsize 6, out_qsize 0
# INFO - 14:05:51: EPOCH 0 - PROGRESS: at 81.15% examples, 224414 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:52: EPOCH 0 - PROGRESS: at 81.83% examples, 224399 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:53: EPOCH 0 - PROGRESS: at 82.48% examples, 224386 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:54: EPOCH 0 - PROGRESS: at 83.16% examples, 224481 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:55: EPOCH 0 - PROGRESS: at 83.85% examples, 224475 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:56: EPOCH 0 - PROGRESS: at 84.52% examples, 224532 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:58: EPOCH 0 - PROGRESS: at 85.17% examples, 224599 words/s, in_qsize 5, out_qsize 0
# INFO - 14:05:59: EPOCH 0 - PROGRESS: at 85.83% examples, 224569 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:00: EPOCH 0 - PROGRESS: at 86.53% examples, 224659 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:01: EPOCH 0 - PROGRESS: at 87.20% examples, 224645 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:02: EPOCH 0 - PROGRESS: at 87.85% examples, 224635 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:03: EPOCH 0 - PROGRESS: at 88.49% examples, 224618 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:04: EPOCH 0 - PROGRESS: at 89.19% examples, 224655 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:05: EPOCH 0 - PROGRESS: at 89.87% examples, 224713 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:06: EPOCH 0 - PROGRESS: at 90.55% examples, 224766 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:07: EPOCH 0 - PROGRESS: at 91.23% examples, 224791 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:08: EPOCH 0 - PROGRESS: at 91.88% examples, 224781 words/s, in_qsize 6, out_qsize 0
# INFO - 14:06:09: EPOCH 0 - PROGRESS: at 92.55% examples, 224805 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:10: EPOCH 0 - PROGRESS: at 93.23% examples, 224907 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:11: EPOCH 0 - PROGRESS: at 93.90% examples, 224888 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:12: EPOCH 0 - PROGRESS: at 94.59% examples, 224971 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:13: EPOCH 0 - PROGRESS: at 95.22% examples, 224961 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:14: EPOCH 0 - PROGRESS: at 95.91% examples, 224973 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:15: EPOCH 0 - PROGRESS: at 96.57% examples, 225004 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:16: EPOCH 0 - PROGRESS: at 97.22% examples, 225054 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:17: EPOCH 0 - PROGRESS: at 97.89% examples, 225058 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:18: EPOCH 0 - PROGRESS: at 98.56% examples, 225038 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:19: EPOCH 0 - PROGRESS: at 99.25% examples, 225104 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:20: EPOCH 0 - PROGRESS: at 99.92% examples, 225156 words/s, in_qsize 4, out_qsize 0
# INFO - 14:06:20: EPOCH 0: training on 44760398 raw words (35114034 effective words) took 155.9s, 225208 effective words/s
# INFO - 14:06:21: EPOCH 1 - PROGRESS: at 0.62% examples, 214964 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:22: EPOCH 1 - PROGRESS: at 1.28% examples, 222947 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:23: EPOCH 1 - PROGRESS: at 1.88% examples, 218478 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:24: EPOCH 1 - PROGRESS: at 2.55% examples, 222116 words/s, in_qsize 6, out_qsize 1
# INFO - 14:06:25: EPOCH 1 - PROGRESS: at 3.24% examples, 224558 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:26: EPOCH 1 - PROGRESS: at 3.94% examples, 225706 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:27: EPOCH 1 - PROGRESS: at 4.63% examples, 226795 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:28: EPOCH 1 - PROGRESS: at 5.30% examples, 227347 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:29: EPOCH 1 - PROGRESS: at 5.95% examples, 226934 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:30: EPOCH 1 - PROGRESS: at 6.60% examples, 227462 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:31: EPOCH 1 - PROGRESS: at 7.25% examples, 227210 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:32: EPOCH 1 - PROGRESS: at 7.89% examples, 226634 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:33: EPOCH 1 - PROGRESS: at 8.54% examples, 226323 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:34: EPOCH 1 - PROGRESS: at 9.22% examples, 226734 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:36: EPOCH 1 - PROGRESS: at 9.88% examples, 227159 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:37: EPOCH 1 - PROGRESS: at 10.53% examples, 227070 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:38: EPOCH 1 - PROGRESS: at 11.17% examples, 226982 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:39: EPOCH 1 - PROGRESS: at 11.77% examples, 226458 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:40: EPOCH 1 - PROGRESS: at 12.44% examples, 226698 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:41: EPOCH 1 - PROGRESS: at 13.12% examples, 226832 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:42: EPOCH 1 - PROGRESS: at 13.79% examples, 227172 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:43: EPOCH 1 - PROGRESS: at 14.43% examples, 226793 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:44: EPOCH 1 - PROGRESS: at 15.15% examples, 227084 words/s, in_qsize 6, out_qsize 0
# INFO - 14:06:45: EPOCH 1 - PROGRESS: at 15.81% examples, 227202 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:46: EPOCH 1 - PROGRESS: at 16.46% examples, 227095 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:47: EPOCH 1 - PROGRESS: at 17.15% examples, 227347 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:48: EPOCH 1 - PROGRESS: at 17.80% examples, 227388 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:49: EPOCH 1 - PROGRESS: at 18.46% examples, 227105 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:50: EPOCH 1 - PROGRESS: at 19.17% examples, 227339 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:51: EPOCH 1 - PROGRESS: at 19.85% examples, 227762 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:52: EPOCH 1 - PROGRESS: at 20.51% examples, 227416 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:53: EPOCH 1 - PROGRESS: at 21.17% examples, 227493 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:54: EPOCH 1 - PROGRESS: at 21.85% examples, 227577 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:55: EPOCH 1 - PROGRESS: at 22.52% examples, 227741 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:56: EPOCH 1 - PROGRESS: at 23.21% examples, 227617 words/s, in_qsize 4, out_qsize 1
# INFO - 14:06:57: EPOCH 1 - PROGRESS: at 23.89% examples, 227959 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:58: EPOCH 1 - PROGRESS: at 24.53% examples, 227782 words/s, in_qsize 5, out_qsize 0
# INFO - 14:06:59: EPOCH 1 - PROGRESS: at 25.20% examples, 227685 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:00: EPOCH 1 - PROGRESS: at 25.87% examples, 227726 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:01: EPOCH 1 - PROGRESS: at 26.54% examples, 227854 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:02: EPOCH 1 - PROGRESS: at 27.15% examples, 227630 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:03: EPOCH 1 - PROGRESS: at 27.79% examples, 227339 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:04: EPOCH 1 - PROGRESS: at 28.45% examples, 227305 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:05: EPOCH 1 - PROGRESS: at 29.10% examples, 227353 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:06: EPOCH 1 - PROGRESS: at 29.77% examples, 227453 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:07: EPOCH 1 - PROGRESS: at 30.44% examples, 227559 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:08: EPOCH 1 - PROGRESS: at 31.09% examples, 227449 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:09: EPOCH 1 - PROGRESS: at 31.75% examples, 227463 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:10: EPOCH 1 - PROGRESS: at 32.43% examples, 227665 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:11: EPOCH 1 - PROGRESS: at 33.11% examples, 227544 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:12: EPOCH 1 - PROGRESS: at 33.78% examples, 227545 words/s, in_qsize 6, out_qsize 0
# INFO - 14:07:13: EPOCH 1 - PROGRESS: at 34.47% examples, 227797 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:14: EPOCH 1 - PROGRESS: at 35.12% examples, 227749 words/s, in_qsize 6, out_qsize 0
# INFO - 14:07:15: EPOCH 1 - PROGRESS: at 35.82% examples, 227775 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:16: EPOCH 1 - PROGRESS: at 36.49% examples, 227874 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:17: EPOCH 1 - PROGRESS: at 37.15% examples, 227889 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:19: EPOCH 1 - PROGRESS: at 37.80% examples, 227628 words/s, in_qsize 6, out_qsize 0
# INFO - 14:07:20: EPOCH 1 - PROGRESS: at 38.47% examples, 227668 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:21: EPOCH 1 - PROGRESS: at 39.16% examples, 227895 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:22: EPOCH 1 - PROGRESS: at 39.78% examples, 227737 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:23: EPOCH 1 - PROGRESS: at 40.43% examples, 227693 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:24: EPOCH 1 - PROGRESS: at 41.12% examples, 227902 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:25: EPOCH 1 - PROGRESS: at 41.73% examples, 227663 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:26: EPOCH 1 - PROGRESS: at 42.40% examples, 227653 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:27: EPOCH 1 - PROGRESS: at 43.06% examples, 227668 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:28: EPOCH 1 - PROGRESS: at 43.71% examples, 227649 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:29: EPOCH 1 - PROGRESS: at 44.35% examples, 227536 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:30: EPOCH 1 - PROGRESS: at 45.00% examples, 227501 words/s, in_qsize 6, out_qsize 1
# INFO - 14:07:31: EPOCH 1 - PROGRESS: at 45.70% examples, 227490 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:32: EPOCH 1 - PROGRESS: at 46.38% examples, 227565 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:33: EPOCH 1 - PROGRESS: at 47.01% examples, 227350 words/s, in_qsize 6, out_qsize 0
# INFO - 14:07:34: EPOCH 1 - PROGRESS: at 47.70% examples, 227386 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:35: EPOCH 1 - PROGRESS: at 48.41% examples, 227575 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:36: EPOCH 1 - PROGRESS: at 49.08% examples, 227587 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:37: EPOCH 1 - PROGRESS: at 49.72% examples, 227577 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:38: EPOCH 1 - PROGRESS: at 50.36% examples, 227554 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:39: EPOCH 1 - PROGRESS: at 51.06% examples, 227540 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:40: EPOCH 1 - PROGRESS: at 51.75% examples, 227532 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:41: EPOCH 1 - PROGRESS: at 52.47% examples, 227607 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:42: EPOCH 1 - PROGRESS: at 53.14% examples, 227567 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:43: EPOCH 1 - PROGRESS: at 53.83% examples, 227739 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:44: EPOCH 1 - PROGRESS: at 54.51% examples, 227792 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:45: EPOCH 1 - PROGRESS: at 55.17% examples, 227756 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:46: EPOCH 1 - PROGRESS: at 55.88% examples, 227797 words/s, in_qsize 6, out_qsize 0
# INFO - 14:07:47: EPOCH 1 - PROGRESS: at 56.58% examples, 227787 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:48: EPOCH 1 - PROGRESS: at 57.27% examples, 227908 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:49: EPOCH 1 - PROGRESS: at 57.92% examples, 227856 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:50: EPOCH 1 - PROGRESS: at 58.60% examples, 227997 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:51: EPOCH 1 - PROGRESS: at 59.30% examples, 228121 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:52: EPOCH 1 - PROGRESS: at 59.93% examples, 227974 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:54: EPOCH 1 - PROGRESS: at 60.57% examples, 227882 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:55: EPOCH 1 - PROGRESS: at 61.23% examples, 227888 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:56: EPOCH 1 - PROGRESS: at 61.92% examples, 228033 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:57: EPOCH 1 - PROGRESS: at 62.59% examples, 228026 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:58: EPOCH 1 - PROGRESS: at 63.23% examples, 227994 words/s, in_qsize 5, out_qsize 0
# INFO - 14:07:59: EPOCH 1 - PROGRESS: at 63.92% examples, 228050 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:00: EPOCH 1 - PROGRESS: at 64.60% examples, 228144 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:01: EPOCH 1 - PROGRESS: at 65.27% examples, 228153 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:02: EPOCH 1 - PROGRESS: at 65.92% examples, 228127 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:03: EPOCH 1 - PROGRESS: at 66.52% examples, 227920 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:04: EPOCH 1 - PROGRESS: at 67.16% examples, 227889 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:05: EPOCH 1 - PROGRESS: at 67.82% examples, 227913 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:06: EPOCH 1 - PROGRESS: at 68.50% examples, 227908 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:07: EPOCH 1 - PROGRESS: at 69.19% examples, 228000 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:08: EPOCH 1 - PROGRESS: at 69.83% examples, 227966 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:09: EPOCH 1 - PROGRESS: at 70.50% examples, 227937 words/s, in_qsize 4, out_qsize 1
# INFO - 14:08:10: EPOCH 1 - PROGRESS: at 71.18% examples, 227933 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:11: EPOCH 1 - PROGRESS: at 71.86% examples, 227970 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:12: EPOCH 1 - PROGRESS: at 72.52% examples, 227992 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:13: EPOCH 1 - PROGRESS: at 73.16% examples, 227972 words/s, in_qsize 4, out_qsize 1
# INFO - 14:08:14: EPOCH 1 - PROGRESS: at 73.85% examples, 228067 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:15: EPOCH 1 - PROGRESS: at 74.52% examples, 228057 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:16: EPOCH 1 - PROGRESS: at 75.21% examples, 228114 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:17: EPOCH 1 - PROGRESS: at 75.89% examples, 228134 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:18: EPOCH 1 - PROGRESS: at 76.54% examples, 228084 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:19: EPOCH 1 - PROGRESS: at 77.20% examples, 228103 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:20: EPOCH 1 - PROGRESS: at 77.87% examples, 228050 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:21: EPOCH 1 - PROGRESS: at 78.52% examples, 228078 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:22: EPOCH 1 - PROGRESS: at 79.14% examples, 227934 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:23: EPOCH 1 - PROGRESS: at 79.82% examples, 228032 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:24: EPOCH 1 - PROGRESS: at 80.46% examples, 227983 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:25: EPOCH 1 - PROGRESS: at 81.12% examples, 228013 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:26: EPOCH 1 - PROGRESS: at 81.76% examples, 227914 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:27: EPOCH 1 - PROGRESS: at 82.44% examples, 227957 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:28: EPOCH 1 - PROGRESS: at 83.10% examples, 227950 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:29: EPOCH 1 - PROGRESS: at 83.77% examples, 227954 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:30: EPOCH 1 - PROGRESS: at 84.45% examples, 227974 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:31: EPOCH 1 - PROGRESS: at 85.11% examples, 228007 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:32: EPOCH 1 - PROGRESS: at 85.74% examples, 227836 words/s, in_qsize 4, out_qsize 1
# INFO - 14:08:33: EPOCH 1 - PROGRESS: at 86.42% examples, 227812 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:34: EPOCH 1 - PROGRESS: at 87.13% examples, 227857 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:35: EPOCH 1 - PROGRESS: at 87.80% examples, 227875 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:36: EPOCH 1 - PROGRESS: at 88.47% examples, 227892 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:38: EPOCH 1 - PROGRESS: at 89.14% examples, 227932 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:39: EPOCH 1 - PROGRESS: at 89.83% examples, 227980 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:40: EPOCH 1 - PROGRESS: at 90.51% examples, 227986 words/s, in_qsize 6, out_qsize 0
# INFO - 14:08:41: EPOCH 1 - PROGRESS: at 91.19% examples, 228027 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:42: EPOCH 1 - PROGRESS: at 91.86% examples, 227993 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:43: EPOCH 1 - PROGRESS: at 92.52% examples, 227971 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:44: EPOCH 1 - PROGRESS: at 93.21% examples, 227991 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:45: EPOCH 1 - PROGRESS: at 93.87% examples, 228027 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:46: EPOCH 1 - PROGRESS: at 94.57% examples, 228075 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:47: EPOCH 1 - PROGRESS: at 95.22% examples, 228090 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:48: EPOCH 1 - PROGRESS: at 95.88% examples, 228103 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:49: EPOCH 1 - PROGRESS: at 96.55% examples, 228111 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:50: EPOCH 1 - PROGRESS: at 97.18% examples, 228088 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:51: EPOCH 1 - PROGRESS: at 97.85% examples, 228074 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:52: EPOCH 1 - PROGRESS: at 98.54% examples, 228160 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:53: EPOCH 1 - PROGRESS: at 99.21% examples, 228161 words/s, in_qsize 6, out_qsize 0
# INFO - 14:08:54: EPOCH 1 - PROGRESS: at 99.87% examples, 228172 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:54: EPOCH 1: training on 44760398 raw words (35114430 effective words) took 153.9s, 228225 effective words/s
# INFO - 14:08:55: EPOCH 2 - PROGRESS: at 0.66% examples, 219625 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:56: EPOCH 2 - PROGRESS: at 1.35% examples, 229478 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:57: EPOCH 2 - PROGRESS: at 1.99% examples, 225879 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:58: EPOCH 2 - PROGRESS: at 2.68% examples, 227577 words/s, in_qsize 5, out_qsize 0
# INFO - 14:08:59: EPOCH 2 - PROGRESS: at 3.37% examples, 229516 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:00: EPOCH 2 - PROGRESS: at 4.03% examples, 228362 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:01: EPOCH 2 - PROGRESS: at 4.72% examples, 228846 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:02: EPOCH 2 - PROGRESS: at 5.37% examples, 227264 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:03: EPOCH 2 - PROGRESS: at 6.03% examples, 227092 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:04: EPOCH 2 - PROGRESS: at 6.71% examples, 227764 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:05: EPOCH 2 - PROGRESS: at 7.39% examples, 227531 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:07: EPOCH 2 - PROGRESS: at 8.07% examples, 227750 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:08: EPOCH 2 - PROGRESS: at 8.74% examples, 228078 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:09: EPOCH 2 - PROGRESS: at 9.40% examples, 227796 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:10: EPOCH 2 - PROGRESS: at 10.03% examples, 227405 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:11: EPOCH 2 - PROGRESS: at 10.70% examples, 227442 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:12: EPOCH 2 - PROGRESS: at 11.35% examples, 227631 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:13: EPOCH 2 - PROGRESS: at 12.02% examples, 227830 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:14: EPOCH 2 - PROGRESS: at 12.66% examples, 227701 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:15: EPOCH 2 - PROGRESS: at 13.34% examples, 228193 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:16: EPOCH 2 - PROGRESS: at 14.01% examples, 227719 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:17: EPOCH 2 - PROGRESS: at 14.71% examples, 228145 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:18: EPOCH 2 - PROGRESS: at 15.39% examples, 228162 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:19: EPOCH 2 - PROGRESS: at 16.04% examples, 228387 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:20: EPOCH 2 - PROGRESS: at 16.66% examples, 228006 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:21: EPOCH 2 - PROGRESS: at 17.34% examples, 228071 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:22: EPOCH 2 - PROGRESS: at 18.00% examples, 228110 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:23: EPOCH 2 - PROGRESS: at 18.68% examples, 228152 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:24: EPOCH 2 - PROGRESS: at 19.34% examples, 228356 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:25: EPOCH 2 - PROGRESS: at 20.03% examples, 228354 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:26: EPOCH 2 - PROGRESS: at 20.72% examples, 228508 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:27: EPOCH 2 - PROGRESS: at 21.39% examples, 228451 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:28: EPOCH 2 - PROGRESS: at 22.02% examples, 228046 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:29: EPOCH 2 - PROGRESS: at 22.70% examples, 228215 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:30: EPOCH 2 - PROGRESS: at 23.38% examples, 227989 words/s, in_qsize 4, out_qsize 1
# INFO - 14:09:31: EPOCH 2 - PROGRESS: at 24.09% examples, 228203 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:32: EPOCH 2 - PROGRESS: at 24.73% examples, 228096 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:33: EPOCH 2 - PROGRESS: at 25.36% examples, 227819 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:34: EPOCH 2 - PROGRESS: at 26.06% examples, 228045 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:35: EPOCH 2 - PROGRESS: at 26.74% examples, 228040 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:36: EPOCH 2 - PROGRESS: at 27.40% examples, 228182 words/s, in_qsize 6, out_qsize 0
# INFO - 14:09:37: EPOCH 2 - PROGRESS: at 28.07% examples, 228089 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:38: EPOCH 2 - PROGRESS: at 28.75% examples, 228124 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:39: EPOCH 2 - PROGRESS: at 29.44% examples, 228389 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:40: EPOCH 2 - PROGRESS: at 30.08% examples, 228134 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:41: EPOCH 2 - PROGRESS: at 30.75% examples, 228245 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:42: EPOCH 2 - PROGRESS: at 31.42% examples, 228144 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:44: EPOCH 2 - PROGRESS: at 32.11% examples, 228123 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:45: EPOCH 2 - PROGRESS: at 32.79% examples, 228276 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:46: EPOCH 2 - PROGRESS: at 33.45% examples, 228222 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:47: EPOCH 2 - PROGRESS: at 34.14% examples, 228431 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:48: EPOCH 2 - PROGRESS: at 34.79% examples, 228367 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:49: EPOCH 2 - PROGRESS: at 35.48% examples, 228481 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:50: EPOCH 2 - PROGRESS: at 36.15% examples, 228563 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:51: EPOCH 2 - PROGRESS: at 36.79% examples, 228504 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:52: EPOCH 2 - PROGRESS: at 37.43% examples, 228470 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:53: EPOCH 2 - PROGRESS: at 38.13% examples, 228383 words/s, in_qsize 6, out_qsize 1
# INFO - 14:09:54: EPOCH 2 - PROGRESS: at 38.80% examples, 228467 words/s, in_qsize 6, out_qsize 0
# INFO - 14:09:55: EPOCH 2 - PROGRESS: at 39.47% examples, 228550 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:56: EPOCH 2 - PROGRESS: at 40.11% examples, 228488 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:57: EPOCH 2 - PROGRESS: at 40.76% examples, 228541 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:58: EPOCH 2 - PROGRESS: at 41.42% examples, 228437 words/s, in_qsize 5, out_qsize 0
# INFO - 14:09:59: EPOCH 2 - PROGRESS: at 42.11% examples, 228479 words/s, in_qsize 5, out_qsize 0
# INFO - 14:10:00: EPOCH 2 - PROGRESS: at 42.75% examples, 228434 words/s, in_qsize 5, out_qsize 0
# INFO - 14:10:01: EPOCH 2 - PROGRESS: at 43.39% examples, 228380 words/s, in_qsize 5, out_qsize 0
# INFO - 14:10:02: EPOCH 2 - PROGRESS: at 44.04% examples, 228355 words/s, in_qsize 5, out_qsize 0
# INFO - 14:10:03: EPOCH 2 - PROGRESS: at 44.64% examples, 228025 words/s, in_qsize 5, out_qsize 0
# INFO - 14:10:04: EPOCH 2 - PROGRESS: at 45.29% examples, 227924 words/s, in_qsize 5, out_qsize 0
# INFO - 14:10:05: EPOCH 2 - PROGRESS: at 45.97% examples, 227976 words/s, in_qsize 5, out_qsize 0
# INFO - 14:10:06: EPOCH 2 - PROGRESS: at 46.65% examples, 228025 words/s, in_qsize 5, out_qsize 0
# INFO - 14:10:07: EPOCH 2 - PROGRESS: at 47.33% examples, 227981 words/s, in_qsize 5, out_qsize 0
# INFO - 14:10:08: EPOCH 2 - PROGRESS: at 47.98% examples, 227832 words/s, in_qsize 5, out_qsize 0
# ...
# INFO - 14:14:06: EPOCH 4 - PROGRESS: at 2.59% examples, 223433 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:07: EPOCH 4 - PROGRESS: at 3.28% examples, 226810 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:08: EPOCH 4 - PROGRESS: at 3.94% examples, 225052 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:09: EPOCH 4 - PROGRESS: at 4.61% examples, 225863 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:10: EPOCH 4 - PROGRESS: at 5.25% examples, 225469 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:11: EPOCH 4 - PROGRESS: at 5.92% examples, 226019 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:12: EPOCH 4 - PROGRESS: at 6.55% examples, 225473 words/s, in_qsize 6, out_qsize 0
# INFO - 14:14:13: EPOCH 4 - PROGRESS: at 7.23% examples, 226065 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:14: EPOCH 4 - PROGRESS: at 7.89% examples, 226650 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:15: EPOCH 4 - PROGRESS: at 8.56% examples, 226923 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:16: EPOCH 4 - PROGRESS: at 9.22% examples, 226836 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:17: EPOCH 4 - PROGRESS: at 9.88% examples, 226906 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:18: EPOCH 4 - PROGRESS: at 10.53% examples, 226682 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:19: EPOCH 4 - PROGRESS: at 11.19% examples, 226893 words/s, in_qsize 6, out_qsize 0
# INFO - 14:14:20: EPOCH 4 - PROGRESS: at 11.82% examples, 226861 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:21: EPOCH 4 - PROGRESS: at 12.51% examples, 227274 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:22: EPOCH 4 - PROGRESS: at 13.10% examples, 226372 words/s, in_qsize 6, out_qsize 1
# INFO - 14:14:23: EPOCH 4 - PROGRESS: at 13.77% examples, 226536 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:24: EPOCH 4 - PROGRESS: at 14.44% examples, 226557 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:25: EPOCH 4 - PROGRESS: at 15.11% examples, 226723 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:26: EPOCH 4 - PROGRESS: at 15.77% examples, 226820 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:27: EPOCH 4 - PROGRESS: at 16.42% examples, 227038 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:28: EPOCH 4 - PROGRESS: at 17.10% examples, 227115 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:29: EPOCH 4 - PROGRESS: at 17.76% examples, 227112 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:30: EPOCH 4 - PROGRESS: at 18.46% examples, 227544 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:31: EPOCH 4 - PROGRESS: at 19.12% examples, 227453 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:32: EPOCH 4 - PROGRESS: at 19.79% examples, 227613 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:33: EPOCH 4 - PROGRESS: at 20.39% examples, 226986 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:34: EPOCH 4 - PROGRESS: at 21.08% examples, 227147 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:35: EPOCH 4 - PROGRESS: at 21.75% examples, 227353 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:36: EPOCH 4 - PROGRESS: at 22.41% examples, 227230 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:37: EPOCH 4 - PROGRESS: at 23.07% examples, 227025 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:38: EPOCH 4 - PROGRESS: at 23.73% examples, 227104 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:39: EPOCH 4 - PROGRESS: at 24.40% examples, 227185 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:40: EPOCH 4 - PROGRESS: at 25.07% examples, 227355 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:41: EPOCH 4 - PROGRESS: at 25.74% examples, 227285 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:42: EPOCH 4 - PROGRESS: at 26.42% examples, 227377 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:43: EPOCH 4 - PROGRESS: at 27.07% examples, 227306 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:44: EPOCH 4 - PROGRESS: at 27.79% examples, 227609 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:45: EPOCH 4 - PROGRESS: at 28.47% examples, 227767 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:46: EPOCH 4 - PROGRESS: at 29.14% examples, 227840 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:47: EPOCH 4 - PROGRESS: at 29.84% examples, 228073 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:48: EPOCH 4 - PROGRESS: at 30.51% examples, 228162 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:50: EPOCH 4 - PROGRESS: at 31.20% examples, 228182 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:51: EPOCH 4 - PROGRESS: at 31.88% examples, 228343 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:52: EPOCH 4 - PROGRESS: at 32.55% examples, 228374 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:53: EPOCH 4 - PROGRESS: at 33.24% examples, 228324 words/s, in_qsize 5, out_qsize 1
# INFO - 14:14:54: EPOCH 4 - PROGRESS: at 33.90% examples, 228430 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:55: EPOCH 4 - PROGRESS: at 34.56% examples, 228495 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:56: EPOCH 4 - PROGRESS: at 35.24% examples, 228510 words/s, in_qsize 6, out_qsize 0
# INFO - 14:14:57: EPOCH 4 - PROGRESS: at 35.91% examples, 228591 words/s, in_qsize 6, out_qsize 0
# INFO - 14:14:58: EPOCH 4 - PROGRESS: at 36.57% examples, 228661 words/s, in_qsize 5, out_qsize 0
# INFO - 14:14:59: EPOCH 4 - PROGRESS: at 37.21% examples, 228582 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:00: EPOCH 4 - PROGRESS: at 37.89% examples, 228647 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:01: EPOCH 4 - PROGRESS: at 38.56% examples, 228690 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:02: EPOCH 4 - PROGRESS: at 39.18% examples, 228499 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:03: EPOCH 4 - PROGRESS: at 39.80% examples, 228106 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:04: EPOCH 4 - PROGRESS: at 40.45% examples, 227983 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:05: EPOCH 4 - PROGRESS: at 41.12% examples, 228047 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:06: EPOCH 4 - PROGRESS: at 41.80% examples, 228053 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:07: EPOCH 4 - PROGRESS: at 42.46% examples, 228127 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:08: EPOCH 4 - PROGRESS: at 43.10% examples, 228100 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:09: EPOCH 4 - PROGRESS: at 43.80% examples, 228176 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:10: EPOCH 4 - PROGRESS: at 44.49% examples, 228353 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:11: EPOCH 4 - PROGRESS: at 45.16% examples, 228398 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:12: EPOCH 4 - PROGRESS: at 45.84% examples, 228444 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:13: EPOCH 4 - PROGRESS: at 46.51% examples, 228460 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:14: EPOCH 4 - PROGRESS: at 47.19% examples, 228506 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:15: EPOCH 4 - PROGRESS: at 47.88% examples, 228679 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:16: EPOCH 4 - PROGRESS: at 48.58% examples, 228666 words/s, in_qsize 6, out_qsize 0
# INFO - 14:15:17: EPOCH 4 - PROGRESS: at 49.28% examples, 228766 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:18: EPOCH 4 - PROGRESS: at 49.94% examples, 228799 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:19: EPOCH 4 - PROGRESS: at 50.63% examples, 228888 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:20: EPOCH 4 - PROGRESS: at 51.33% examples, 228989 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:21: EPOCH 4 - PROGRESS: at 51.97% examples, 228922 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:22: EPOCH 4 - PROGRESS: at 52.65% examples, 228881 words/s, in_qsize 6, out_qsize 0
# INFO - 14:15:23: EPOCH 4 - PROGRESS: at 53.34% examples, 228960 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:24: EPOCH 4 - PROGRESS: at 54.03% examples, 229106 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:25: EPOCH 4 - PROGRESS: at 54.69% examples, 229121 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:26: EPOCH 4 - PROGRESS: at 55.35% examples, 229163 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:27: EPOCH 4 - PROGRESS: at 56.04% examples, 229157 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:28: EPOCH 4 - PROGRESS: at 56.74% examples, 229125 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:29: EPOCH 4 - PROGRESS: at 57.43% examples, 229165 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:31: EPOCH 4 - PROGRESS: at 58.09% examples, 229178 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:32: EPOCH 4 - PROGRESS: at 58.78% examples, 229184 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:33: EPOCH 4 - PROGRESS: at 59.46% examples, 229141 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:34: EPOCH 4 - PROGRESS: at 60.15% examples, 229226 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:35: EPOCH 4 - PROGRESS: at 60.81% examples, 229208 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:36: EPOCH 4 - PROGRESS: at 61.50% examples, 229293 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:37: EPOCH 4 - PROGRESS: at 62.16% examples, 229226 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:38: EPOCH 4 - PROGRESS: at 62.84% examples, 229245 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:39: EPOCH 4 - PROGRESS: at 63.47% examples, 229143 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:40: EPOCH 4 - PROGRESS: at 64.16% examples, 229212 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:41: EPOCH 4 - PROGRESS: at 64.85% examples, 229209 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:42: EPOCH 4 - PROGRESS: at 65.53% examples, 229229 words/s, in_qsize 4, out_qsize 1
# INFO - 14:15:43: EPOCH 4 - PROGRESS: at 66.23% examples, 229254 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:44: EPOCH 4 - PROGRESS: at 66.87% examples, 229223 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:45: EPOCH 4 - PROGRESS: at 67.53% examples, 229243 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:46: EPOCH 4 - PROGRESS: at 68.23% examples, 229317 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:47: EPOCH 4 - PROGRESS: at 68.90% examples, 229340 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:48: EPOCH 4 - PROGRESS: at 69.57% examples, 229346 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:49: EPOCH 4 - PROGRESS: at 70.27% examples, 229344 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:50: EPOCH 4 - PROGRESS: at 70.96% examples, 229428 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:51: EPOCH 4 - PROGRESS: at 71.61% examples, 229372 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:52: EPOCH 4 - PROGRESS: at 72.29% examples, 229406 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:53: EPOCH 4 - PROGRESS: at 72.95% examples, 229327 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:54: EPOCH 4 - PROGRESS: at 73.65% examples, 229344 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:55: EPOCH 4 - PROGRESS: at 74.33% examples, 229380 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:56: EPOCH 4 - PROGRESS: at 74.99% examples, 229358 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:57: EPOCH 4 - PROGRESS: at 75.67% examples, 229371 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:58: EPOCH 4 - PROGRESS: at 76.34% examples, 229347 words/s, in_qsize 5, out_qsize 0
# INFO - 14:15:59: EPOCH 4 - PROGRESS: at 77.03% examples, 229354 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:00: EPOCH 4 - PROGRESS: at 77.71% examples, 229445 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:01: EPOCH 4 - PROGRESS: at 78.34% examples, 229389 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:02: EPOCH 4 - PROGRESS: at 78.97% examples, 229297 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:03: EPOCH 4 - PROGRESS: at 79.61% examples, 229266 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:04: EPOCH 4 - PROGRESS: at 80.26% examples, 229306 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:05: EPOCH 4 - PROGRESS: at 80.90% examples, 229275 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:06: EPOCH 4 - PROGRESS: at 81.56% examples, 229291 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:07: EPOCH 4 - PROGRESS: at 82.24% examples, 229331 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:08: EPOCH 4 - PROGRESS: at 82.90% examples, 229335 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:10: EPOCH 4 - PROGRESS: at 83.57% examples, 229303 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:11: EPOCH 4 - PROGRESS: at 84.29% examples, 229311 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:12: EPOCH 4 - PROGRESS: at 84.96% examples, 229351 words/s, in_qsize 4, out_qsize 1
# INFO - 14:16:13: EPOCH 4 - PROGRESS: at 85.63% examples, 229340 words/s, in_qsize 5, out_qsize 1
# INFO - 14:16:14: EPOCH 4 - PROGRESS: at 86.33% examples, 229380 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:15: EPOCH 4 - PROGRESS: at 87.04% examples, 229465 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:16: EPOCH 4 - PROGRESS: at 87.71% examples, 229421 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:17: EPOCH 4 - PROGRESS: at 88.38% examples, 229437 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:18: EPOCH 4 - PROGRESS: at 89.03% examples, 229410 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:19: EPOCH 4 - PROGRESS: at 89.74% examples, 229503 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:20: EPOCH 4 - PROGRESS: at 90.41% examples, 229538 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:21: EPOCH 4 - PROGRESS: at 91.10% examples, 229539 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:22: EPOCH 4 - PROGRESS: at 91.79% examples, 229623 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:23: EPOCH 4 - PROGRESS: at 92.44% examples, 229569 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:24: EPOCH 4 - PROGRESS: at 93.10% examples, 229542 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:25: EPOCH 4 - PROGRESS: at 93.76% examples, 229569 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:26: EPOCH 4 - PROGRESS: at 94.46% examples, 229534 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:27: EPOCH 4 - PROGRESS: at 95.11% examples, 229552 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:28: EPOCH 4 - PROGRESS: at 95.80% examples, 229611 words/s, in_qsize 6, out_qsize 0
# INFO - 14:16:29: EPOCH 4 - PROGRESS: at 96.46% examples, 229583 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:30: EPOCH 4 - PROGRESS: at 97.16% examples, 229649 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:31: EPOCH 4 - PROGRESS: at 97.83% examples, 229680 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:32: EPOCH 4 - PROGRESS: at 98.52% examples, 229747 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:33: EPOCH 4 - PROGRESS: at 99.12% examples, 229586 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:34: EPOCH 4 - PROGRESS: at 99.80% examples, 229588 words/s, in_qsize 5, out_qsize 0
# INFO - 14:16:34: EPOCH 4: training on 44760398 raw words (35111972 effective words) took 152.9s, 229653 effective words/s
# INFO - 14:16:34: Word2Vec lifecycle event {'msg': 'training on 223801990 raw words (175560563 effective words) took 770.1s, 227963 effective words/s', 'datetime': '2022-08-24T14:16:34.863760', 'gensim': '4.2.0', 'python': '3.9.13 | packaged by conda-forge | (main, May 27 2022, 16:56:21) \n[GCC 10.3.0]', 'platform': 'Linux-4.14.287-215.504.amzn2.x86_64-x86_64-with-glibc2.31', 'event': 'train'}
# INFO - 14:16:34: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=199656, vector_size=100, alpha=0.01>', 'datetime': '2022-08-24T14:16:34.864421', 'gensim': '4.2.0', 'python': '3.9.13 | packaged by conda-forge | (main, May 27 2022, 16:56:21) \n[GCC 10.3.0]', 'platform': 'Linux-4.14.287-215.504.amzn2.x86_64-x86_64-with-glibc2.31', 'event': 'created'}
# CPU times: user 39min 37s, sys: 15.2 s, total: 39min 52s
# Wall time: 15min 22s
#                         subgroup  subgroup_size  subgroup_auc  bpsn_auc  \
# 2      homosexual_gay_or_lesbian            537      0.648219  0.760493
# 6                          black            765      0.705002  0.651030
# 7                          white           1230      0.722561  0.614534
# 8  psychiatric_or_mental_illness            259      0.734109  0.763102
# 5                         muslim           1011      0.738836  0.732673
# 4                         jewish            410      0.744916  0.781567
# 0                           male           2174      0.757363  0.686715
# 1                         female           2513      0.775088  0.733113
# 3                      christian           2076      0.784471  0.828803
#
#    bnsp_auc
# 2  0.752656
# 6  0.859183
# 7  0.893683
# 8  0.797917
# 5  0.832328
# 4  0.799293
# 0  0.873649
# 1  0.856349
# 3  0.781694

# %%
FINAL_SCORE = get_final_metric(bias_metrics_df, calculate_overall_auc(test_df, oof_name))
print(f"FINAL SCORE IS {FINAL_SCORE}")
# Out:
# FINAL SCORE IS 0.7700041118068204

# %% [markdown]
# ## Pretrained Model

# %%
w2v_model = api.load("glove-wiki-gigaword-50")
# Out:
# INFO - 14:18:53: loading projection weights from /home/studio-lab-user/gensim-data/glove-wiki-gigaword-50/glove-wiki-gigaword-50.gz
# INFO - 14:19:06: KeyedVectors lifecycle event {'msg': 'loaded (400000, 50) matrix of type float32 from /home/studio-lab-user/gensim-data/glove-wiki-gigaword-50/glove-wiki-gigaword-50.gz', 'binary': False, 'encoding': 'utf8', 'datetime': '2022-08-24T14:19:06.592284', 'gensim': '4.2.0', 'python': '3.9.13 | packaged by conda-forge | (main, May 27 2022, 16:56:21) \n[GCC 10.3.0]', 'platform': 'Linux-4.14.287-215.504.amzn2.x86_64-x86_64-with-glibc2.31', 'event': 'load_word2vec_format'}

# %%
class GlovoWord2VecVectorizer(BaseEstimator, TransformerMixin):
    """
    Word vectors are averaged across to create the document-level vectors/features.
    gensim's own gensim.sklearn_api.W2VTransformer doesn't support out of vocabulary words,
    hence we roll out our own.
    All the parameters are gensim.models.Word2Vec's parameters.
    https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.Word2Vec
    """

    def __init__(self, model):
        self.model = model
        self.vector_size = model.vector_size

    def fit(self, X, y): # what are X and y?
        return self

    def transform(self, X):
        X_embeddings = np.array([self._get_embedding(words) for words in tqdm(X)])
        return X_embeddings

    def _get_embedding(self, words):
        valid_words = [word for word in words if word in self.model.key_to_index]
        if valid_words:
            embedding = np.zeros((len(valid_words), self.vector_size), dtype=np.float32)
            for idx, word in enumerate(valid_words):
                embedding[idx] = self.model[word]

            return np.mean(embedding, axis=0)
        else:
            return np.zeros(self.vector_size)

# %%
glovo_word2vec_tr = GlovoWord2VecVectorizer(w2v_model)
# xgb = XGBClassifier(learning_rate=0.01, n_estimators=100, n_jobs=-1)
lg = LogisticRegression(max_iter=10_000)

# %%
# %%time

#1_000_000

pipeline2 = Pipeline([
    ('glovo', glovo_word2vec_tr), 
    ('LogReg', lg)
])
pipeline2.fit(train_lists, y_train)
oof_name = 'predicted_target'
test_df[oof_name] = pipeline2.predict_proba(test_lists)[:, 1]
oof_name = 'predicted_target'
bias_metrics_df = compute_bias_metrics_for_model(test_df, identity_columns, oof_name, 'toxicity')
bias_metrics_df
# Out:
# 100%|██████████| 902855/902855 [01:51<00:00, 8115.02it/s]
# 100%|██████████| 97145/97145 [00:11<00:00, 8332.89it/s]
# CPU times: user 3min 30s, sys: 31.4 s, total: 4min 1s
# Wall time: 2min 37s
#                         subgroup  subgroup_size  subgroup_auc  bpsn_auc  \
# 2      homosexual_gay_or_lesbian            537      0.626855  0.653670
# 6                          black            765      0.694175  0.597202
# 8  psychiatric_or_mental_illness            259      0.706906  0.773062
# 4                         jewish            410      0.710630  0.643902
# 7                          white           1230      0.710982  0.587918
# 0                           male           2174      0.713457  0.597702
# 1                         female           2513      0.738226  0.661290
# 5                         muslim           1011      0.742216  0.648065
# 3                      christian           2076      0.774936  0.766574
#
#    bnsp_auc
# 2  0.763716
# 6  0.846580
# 8  0.715572
# 4  0.824889
# 7  0.854670
# 0  0.858928
# 1  0.831337
# 5  0.842073
# 3  0.779131

# %%
FINAL_SCORE = get_final_metric(bias_metrics_df, calculate_overall_auc(test_df, oof_name))
print(f"FINAL SCORE IS {FINAL_SCORE}")
# Out:
# FINAL SCORE IS 0.7318606377659689
